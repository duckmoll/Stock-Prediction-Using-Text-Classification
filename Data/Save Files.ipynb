# %%
import boto3
import pandas as pd

# %%
mapping = pd.read_csv("mapping_with_label_training.csv")
mapping = mapping.drop(["date", "cik", "url"], axis=1)
mapping["file_number"] = mapping["file_number"].astype(str)
mapping = mapping.set_index('file_number')
mapping["content"] = None
mapping = mapping[mapping["ticker"] == "AAP"]
mapping
# Out:
#             ticker form_type  label content
# file_number
# 547            AAP         4     -1    None
# 548            AAP         4     -1    None
# 549            AAP         4     -1    None
# 550            AAP         4     -1    None
# 551            AAP         4     -1    None
# ...            ...       ...    ...     ...
# 518456         AAP         4      1    None
# 518457         AAP         4      1    None
# 518458         AAP         4      1    None
# 518459         AAP         4      1    None
# 520339         AAP         4     -1    None
#
# [564 rows x 4 columns]

# %%
s3 = boto3.resource('s3',aws_access_key_id='AKIA3C4YDMBS7EBVW6D6',
    aws_secret_access_key='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')
for file_number in list(mapping.index):
    obj = s3.Object('sec-files-text-predict-stock',
                    "embedding_cleaned/" + file_number+".txt")
    body = obj.get()['Body'].read().decode('utf-8')
    if len(body) > 2000:
        clean = body[:1000] + body[-1000:]
    else:
        clean = body
    print(clean)
# Out:
# shares issuer common stock acquired pursuant dividend reinvestment feature
# shares issuer common stock acquired pursuant dividend reinvestment feature
# shares issuer common stock acquired pursuant dividend reinvestment feature
# shares issuer common stock acquired pursuant dividend reinvestment feature
# shares issuer common stock acquired pursuant dividend reinvestment feature
# shares issuer common stock acquired pursuant dividend reinvestment feature
# shares issuer common stock acquired pursuant dividend reinvestment feature
# grantor retained annuity trust shares issuer common stock acquired dividend reinvestment feature reporting person contributed shares common stock grantor retained annuity trust reporting person sole trustee annuitant term
# securities beneficially owned amended reflect additional shares purchased inadvertently excluded initial
#
#
# ...

# %%
import boto3
from tqdm import tqdm

s3 = boto3.resource('s3',aws_access_key_id='AKIA3C4YDMBS7EBVW6D6',
    aws_secret_access_key='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')
bucket = s3.Bucket('sec-files-text-predict-stock')
with tqdm(total=444552) as pbar:
    for obj in bucket.objects.filter(Prefix="embedding_cleaned/"):
        filename = obj.key
        body = obj.get()['Body'].read().decode("utf-8")
        if len(body) == 0:
            continue
        mapping.loc[filename, "content"] = body
        pbar.update()
# Out:
#   0%|                                   | 819/444552 [01:24<12:46:35,  9.65it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/16/3l2k04x11kbfb0d2vtnzb0_h0000gn/T/ipykernel_3574/4123151828.py in <module>
#       8     for obj in bucket.objects.filter(Prefix="embedding_cleaned/"):
#       9         filename = obj.key
# ---> 10         body = obj.get()['Body'].read().decode("utf-8")
#      11         if len(body) == 0:
#      12             continue
#
# ~/miniforge3/lib/python3.9/site-packages/boto3/resources/factory.py in do_action(self, *args, **kwargs)
#     518             # instance via ``self``.
#     519             def do_action(self, *args, **kwargs):
# --> 520                 response = action(self, *args, **kwargs)
#     521
#     522                 if hasattr(self, 'load'):
#
# ...
