# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
data = pd.read_csv("/content/drive/MyDrive/nlp/rnn.csv")
data.head(3)
print(confusion_matrix(data["label"], data["preds"]))
print(classification_report(data["label"], data["preds"]))
# Out:
# [[9815 6271]
#  [9685 6798]]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.61      0.55     16086
#          1.0       0.52      0.41      0.46     16483
#
#     accuracy                           0.51     32569
#    macro avg       0.51      0.51      0.51     32569
# weighted avg       0.51      0.51      0.51     32569

# %%
data = pd.read_csv("/content/drive/MyDrive/nlp/bog_naive.csv")
print(confusion_matrix(data["label"], data["preds"]))
print(classification_report(data["label"], data["preds"]))
# Out:
# [[11651  4435]
#  [11464  5019]]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.72      0.59     16086
#          1.0       0.53      0.30      0.39     16483
#
#     accuracy                           0.51     32569
#    macro avg       0.52      0.51      0.49     32569
# weighted avg       0.52      0.51      0.49     32569

# %%
data = pd.read_csv("/content/drive/MyDrive/nlp/tfidf_naive.csv")
print(confusion_matrix(data["label"], data["preds"]))
print(classification_report(data["label"], data["preds"]))
# Out:
# [[8338 7748]
#  [9260 7223]]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.52      0.50     16086
#          1.0       0.48      0.44      0.46     16483
#
#     accuracy                           0.48     32569
#    macro avg       0.48      0.48      0.48     32569
# weighted avg       0.48      0.48      0.48     32569

# %%
# rnn_embedding
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/nlp/rnn_embedding.csv")
print(confusion_matrix(data["label"], data["preds"]))
print(classification_report(data["label"], data["preds"]))
# Out:
# [[9289 6797]
#  [8884 7599]]
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.58      0.54     16086
#          1.0       0.53      0.46      0.49     16483
#
#     accuracy                           0.52     32569
#    macro avg       0.52      0.52      0.52     32569
# weighted avg       0.52      0.52      0.52     32569

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/nlp/rnn_embedding_5d.csv")
print(confusion_matrix(data["label"], data["preds"]))
print(classification_report(data["label"], data["preds"]))
# Out:
# [[12351  4286]
#  [12179  3753]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.74      0.60     16637
#            1       0.47      0.24      0.31     15932
#
#     accuracy                           0.49     32569
#    macro avg       0.49      0.49      0.46     32569
# weighted avg       0.49      0.49      0.46     32569

# %%
data = pd.read_csv("/content/drive/MyDrive/nlp/bert_preds.csv")
print(confusion_matrix(data["label"], data["preds"]))
print(classification_report(data["label"], data["preds"]))
# Out:
# [[28719   976]
#  [28579   880]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.97      0.66     29695
#            1       0.47      0.03      0.06     29459
#
#     accuracy                           0.50     59154
#    macro avg       0.49      0.50      0.36     59154
# weighted avg       0.49      0.50      0.36     59154

# %%
data = pd.read_csv("/content/drive/MyDrive/nlp/word_embedding_rft.csv")
print(confusion_matrix(data["label"], data["pred"]))
print(classification_report(data["label"], data["pred"]))
# Out:
# [[17914 11781]
#  [17786 11673]]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55     29695
#          1.0       0.50      0.40      0.44     29459
#
#     accuracy                           0.50     59154
#    macro avg       0.50      0.50      0.49     59154
# weighted avg       0.50      0.50      0.49     59154
