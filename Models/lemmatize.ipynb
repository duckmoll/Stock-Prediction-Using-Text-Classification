# %%
import pandas as pd
import spacy
from spacy.language import Language

pipeline = spacy.load("en_core_web_sm", disable=["ner", "parser","tagger"])

@Language.component("lemma")
def lemmatize(doc):
    tokens = [token for token in doc ]
    tokens = [token.lemma_.lower().strip() for token in tokens]
    tokens = [token for token in tokens if token]
    return " ".join(tokens)
pipeline.add_pipe("lemma")
# Out:
# <function __main__.lemmatize>

# %%
# pip install spacy --upgrade

# %%
train_all = pd.read_csv("/content/drive/MyDrive/nlp/training_content_all.csv", index_col=0).dropna()
docs = train_all["content"].tolist()

# %%
from tqdm import tqdm
new_docs = []
with tqdm(total=len(docs)) as bar:
    for doc in docs:
        new_docs.append(pipeline(doc))
        bar.update()
train_all["content"] = new_docs
train_all
# Out:
#   0%|          | 0/262754 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
#   7%|▋         | 19195/262754 [19:25<4:06:28, 16.47it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-df1ca92267af> in <module>()
#       4 with tqdm(total=len(docs)) as bar:
#       5     for doc in docs:
# ----> 6         new_docs.append(pipeline(doc))
#       7         bar.update()
#       8 train_all["content"] = new_docs
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
# ...

# %%
test.to_csv("/content/drive/MyDrive/nlp/training_content_all_lemmatized.csv")
